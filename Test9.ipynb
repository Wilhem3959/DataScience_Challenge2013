# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import collections
import csv
from itertools import groupby 
import operator

# %%
df = pd.DataFrame(pd.read_csv('hubway_trips.csv'))
df['start_date'] = pd.to_datetime(df.start_date)

# %%
register = df['subsc_type'] == 'Registered'
df_register = df[register]

# %%
baby_faces = df_register['birth_date'].values > 1989

madrugados = df_register.start_date.dt.hour == 2

print(baby_faces)
# Out:
# [False False False ... False False False]
# C:\Users\wilhe\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.

# %%
df_young = df_register[baby_faces]
df_early = df_register[madrugados]

men = df_register['gender'] == 'Male'
wamen = df_register['gender'] == 'Female'

df_zzz_under25 = df_register[baby_faces & madrugados]
df_zzz = df_register[madrugados]

df_zzz_male_under25 = df_register[baby_faces & madrugados & men]
df_zzz_female_under25 = df_register[baby_faces & madrugados & wamen]
# Out:
#         seq_id  hubway_id  status  duration          start_date  strt_statn  \
# 25774    25775      28598  Closed      1055 2011-08-21 02:29:00        23.0
# 25785    25786      28611  Closed      1083 2011-08-21 02:48:00        52.0
# 43954    43955      50572  Closed       889 2011-09-05 02:08:00        44.0
# 43965    43966      50585  Closed       411 2011-09-05 02:25:00        21.0
# 47151    47152      54140  Closed       100 2011-09-09 02:12:00        46.0
# 48627    48628      55747  Closed       726 2011-09-10 02:11:00         5.0
# 48630    48631      55750  Closed       300 2011-09-10 02:12:00        16.0
# 50348    50349      57673  Closed      1360 2011-09-11 02:14:00        42.0
# 59497    59498      67757  Closed       435 2011-09-17 02:05:00        16.0
# 68561    68562      77753  Closed       693 2011-09-24 02:26:00        41.0
# 69885    69886      79262  Closed       574 2011-09-25 02:15:00        53.0
# ...
